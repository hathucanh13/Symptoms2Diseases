# %%
import joblib
import pandas as pd
import numpy as np
# from sentence_transformers import SentenceTransformer

# %%
df = pd.read_csv('archive/dataset_Diseases_and_Symptoms.csv')

# %%
target_disease = "eczema"
filtered_df = df[df["diseases"] == target_disease]
fil = filtered_df.apply(lambda row: row[row == 1], axis = 1)
fil.insert(0, 'diseases', target_disease)

# %%
fil.head()
# Out:
#        diseases  abnormal appearing skin  acne or pimples  allergic reaction  \
# 242753   eczema                      NaN              NaN                NaN
# 242754   eczema                      1.0              NaN                NaN
# 242755   eczema                      1.0              1.0                1.0
# 242756   eczema                      NaN              1.0                1.0
# 242757   eczema                      NaN              1.0                1.0
#
#         cough  irregular appearing scalp  itching of skin  \
# 242753    NaN                        1.0              NaN
# 242754    1.0                        1.0              1.0
# 242755    NaN                        NaN              NaN
# 242756    NaN                        1.0              NaN
# 242757    NaN                        1.0              NaN
#
#         skin dryness, peeling, scaliness, or roughness  skin irritation  \
# 242753                                             NaN              1.0
# ...

# %%
target_disease = "asthma"
filtered_df = df[df["diseases"] == target_disease]
fil = filtered_df.apply(lambda row: row[row == 1], axis = 1)
fil.insert(0, 'diseases', target_disease)

# %%
fil.head()
# Out:
#       diseases  allergic reaction  chest tightness  coryza  cough  \
# 12974   asthma                1.0              NaN     1.0    NaN
# 12975   asthma                1.0              NaN     1.0    NaN
# 12976   asthma                NaN              1.0     1.0    NaN
# 12977   asthma                NaN              NaN     NaN    1.0
# 12978   asthma                1.0              1.0     1.0    NaN
#
#        coughing up sputum  difficulty breathing  fever  nasal congestion  \
# 12974                 1.0                   NaN    1.0               NaN
# 12975                 1.0                   NaN    1.0               NaN
# 12976                 1.0                   1.0    1.0               NaN
# 12977                 NaN                   NaN    1.0               NaN
# 12978                 NaN                   NaN    1.0               NaN
#
#        sharp chest pain  shortness of breath  wheezing
# 12974               1.0                  NaN       1.0
# ...
